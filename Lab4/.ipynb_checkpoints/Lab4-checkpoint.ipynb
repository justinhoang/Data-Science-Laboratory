# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.patches as mpatches
# %matplotlib inline

# %% [markdown]
# ### 1.1

# %%
u1 = [0, 0, 0]
covMatrix1 = [[0.5, 0, 0], [0, 0.5, 0], [0, 0, 0.7]]

u2 = [1, 1, 1]
covMatrix2 = [[0.5, 0, 0], [0, 0.5, 0], [0, 0, 0.1]]

#generate 20 random points from a Gaussian multivariate distribution
x1, y1, z1 = np.random.multivariate_normal(u1, covMatrix1, 20).T
x2, y2, z2 = np.random.multivariate_normal(u2, covMatrix2, 20).T

matrix1 = np.column_stack((x1,y1,z1))
matrix2 = np.column_stack((x2,y2,z2))

#plot 3D plot of the clouds of data points
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(x1, y1, z1, c='r', marker='o')
ax.scatter(x2, y2, z2, c='b', marker='o')
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')

red_patch = mpatches.Patch(color='red', label='label1')
blue_patch = mpatches.Patch(color='blue', label='label2')
plt.legend(handles=[red_patch, blue_patch])

plt.show()

# %% [markdown]
# ### 1.2

# %% [markdown]
# We see that label 2 is offset to the right of label 1. This makes sense since label 2 is centered at a mean, right of label 1. However, the two distributions are hard to distinguish between with some overlap in the middle.

# %%
#concatenate all the points
#x = np.append(x1,x2)
#y = np.append(y1,y2)
#z = np.append(z1,z2)

#matrix = np.column_stack((x,y,z))

# %% [markdown]
# ### 1.3

# %%
#concatenate all the points
x = np.append(x1,x2)
y = np.append(y1,y2)
z = np.append(z1,z2)

matrix = np.column_stack((x,y,z))

#find the covariance matrix:
mean = np.mean(matrix, axis=0)

#find the variances
varX = np.sum(np.square(matrix[:,0]-mean[0]))/len(matrix)
varY = np.sum(np.square(matrix[:,1]-mean[1]))/len(matrix)
varZ = np.sum(np.square(matrix[:,2]-mean[2]))/len(matrix)

#find the covariances
CovXY = np.sum((matrix[:,0]-mean[0]) * (matrix[:,1]-mean[1]))/len(matrix)
CovXZ = np.sum((matrix[:,0]-mean[0]) * (matrix[:,2]-mean[2]))/len(matrix)
CovYZ = np.sum((matrix[:,1]-mean[1]) * (matrix[:,2]-mean[2]))/len(matrix)

covMatrix = np.array([[varX, CovXY, CovXZ], [CovXY, varY, CovYZ], [CovXZ, CovYZ, varZ]])

print ("The covariance matrix is:")
print (covMatrix)
# Out:
# The covariance matrix is:
# [[0.51689504 0.20042474 0.11872641]
#  [0.20042474 0.91534302 0.22788096]
#  [0.11872641 0.22788096 0.66859697]]

# %% [markdown]
# ### 1.4

# %%
from collections import OrderedDict

#find the eigenvectors of the covariance matrix with the largen eigenvalues

#make a dictionary of eigenvalues and their eigenvectors
dictEig = {}
matEig = np.linalg.eig(covMatrix)

for vec in range(len(matEig[0])):
    dictEig[matEig[0][vec]] = matEig[1][:, vec]
    
#sort dictionary
sortedDict = OrderedDict(sorted(dictEig.items(), key = lambda t: t[0], reverse = True))

#top 2 eigenvectors
e1 = list(sortedDict.values())[0]
e2 = list(sortedDict.values())[1]

# %%
eigenv = np.column_stack((e1.T, e2.T))

#project data onto eigenvectors
proj1 = np.dot(matrix1, eigenv)
proj2 = np.dot(matrix2, eigenv)

newx1 = proj1[:, 0]
newy1 = proj1[:, 1]

newx2 = proj2[:, 0]
newy2 = proj2[:, 1]

#plot the projected points
plt.plot(newx1, newy1, "o", c= 'r')
plt.plot(newx2, newy2, "o", c= 'b')

red_patch = mpatches.Patch(color='red', label='label1')
blue_patch = mpatches.Patch(color='blue', label='label2')
plt.legend(handles=[red_patch, blue_patch])

plt.show()

# %% [markdown]
# Yes, PCA did make is easier to distinguish the two labels in two dimensions (label 2 is clearly offset to the right of lablel 1). The variance of the points is clear in the x and y axes with the third dimension gone.

# %% [markdown]
# ### 2.1

# %%
import scipy as sp
import matplotlib.pyplot as plt
from scipy.misc import imread
from scipy import linalg
import numpy as np
# %matplotlib inline

monaLisa = imread("mona_lisa.png",flatten = True)
plt.imshow(monaLisa, cmap='gray')
plt.show()
# Out:
# C:\Users\jakho\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
U, S, V = np.linalg.svd(monaLisa, full_matrices = False)

# %%
#print('%s %d' % (name, number))

def LRA(k):
    print ("For rank %d" %(k))
    
    #resize U, S, V by the rank
    Ut = U[:, :k]
    St = S[:k]
    Vt = V[:k, :]
    
    #calculate low-rank approximation 
    At = Ut.dot(np.diag(St).dot(Vt))
    plt.imshow(At, cmap='gray')
    
    #calculate number of bits needed
    n = Ut.shape[0]
    p = Vt.shape[1]
    bits = 16 * ( k * (n + p + 1))
    print ("Number of bits needed is %d" %(bits))

# %%
LRA(2)
# Out:
# For rank 2
# Number of bits needed is 32128

# %%
LRA(5)
# Out:
# For rank 5
# Number of bits needed is 80320

# %%
LRA(10)
# Out:
# For rank 10
# Number of bits needed is 160640

# %% [markdown]
# ### 3

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.decomposition import PCA
# %matplotlib inline

# %%
mat1 = pd.read_csv("CorrMat1.csv", header=None)
mat3 = pd.read_csv("CorrMat3.csv", header=None)

# %%
plt.matshow(mat1)
plt.xticks([])
plt.yticks([])
plt.title("Original CorrMat1")
plt.show()
print("The sharp yellow dots in the visualization appear to be the corrupted or outlier values.")

print("A way to get rid of these corrupt values with PCA would be using it to construct a rank-1 approximation of the",
      "original matrix.")
pca = PCA(n_components=1)
mat1_pca = pca.fit_transform(mat1)
mat1_new = pca.inverse_transform(mat1_pca)

plt.matshow(mat1_new)
plt.xticks([])
plt.yticks([])
plt.title("New CorrMat1")
plt.show()

print("The result matrix appears to have removed the outliers, and the approximation retains", pca.explained_variance_ratio_[0]*100,
      "percent of the variance in the original matrix.")
# Out:
# The sharp yellow dots in the visualization appear to be the corrupted or outlier values.
# A way to get rid of these corrupt values with PCA would be using it to construct a rank-1 approximation of the original matrix.
# The result matrix appears to have removed the outliers, and the approximation retains 73.25545362617719 percent of the variance in the original matrix.

# %%
plt.matshow(mat3)
plt.xticks([])
plt.yticks([])
plt.title("Original CorrMat3")
plt.show()
print("In this case, the corrupt values are less obvious, but it there seems to be noise that makes the matrix not", 
      "symmetric.")

print("We use PCA again to construct a rank-1 approximation of the original matrix.")

pca = PCA(n_components=1)
mat3_pca = pca.fit_transform(mat3)
mat3_new = pca.inverse_transform(mat3_pca)

plt.matshow(mat3_new)
plt.xticks([])
plt.yticks([])
plt.title("New CorrMat1")
plt.show()

print("The result matrix appears to have greatly reduced the noise, and the approximation retains", pca.explained_variance_ratio_[0]*100,
      "percent of the variance in the original matrix.")
# Out:
# In this case, the corrupt values are less obvious, but it there seems to be noise that makes the matrix not symmetric.
# We use PCA again to construct a rank-1 approximation of the original matrix.
# The result matrix appears to have greatly reduced the noise, and the approximation retains 80.26420467540257 percent of the variance in the original matrix.
